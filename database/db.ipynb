# %%
import pandas as pd
from sqlalchemy import *

db_path = 'postgresql://eqpytyddkgzpje:589827916509690e9baa1abd869d99bd85ac3c9902c361d04c1e560c2befd624@ec2-52-54-38-229.compute-1.amazonaws.com:5432/dap64di8scvd9n'
pd.options.display.max_rows = 999

eng = create_engine(db_path)

# %%
pd.read_sql('''select * from "Annotation" order by id desc''',eng).head(30)
# Out:
#      id                             survey_id  recording_id  source_count  \
# 0   121  a539086c-5c3c-46ab-8d17-8f7586ad67f7           108             2
# 1   120  a539086c-5c3c-46ab-8d17-8f7586ad67f7           193             3
# 2   119  11c6a92b-82be-41da-bc7c-dc9a3e70858d            35             2
# 3   118  11c6a92b-82be-41da-bc7c-dc9a3e70858d           193             3
# 4   117  3f1f7523-f317-4511-9985-6eeaf6c39d02            38             4
# 5   116  3f1f7523-f317-4511-9985-6eeaf6c39d02           193             3
# 6   115  ce709583-1555-4d03-9be0-82fb6c19a1a9           169             4
# 7   114  ce709583-1555-4d03-9be0-82fb6c19a1a9           193             3
# 8   113  f513e6f2-53be-4b4f-a0ba-766a7a44952c           116             3
# 9   112  f513e6f2-53be-4b4f-a0ba-766a7a44952c           193             3
# 10  111  f5bdaabc-df8e-424e-bd55-56b4173113d3           109             2
# 11  110  f5bdaabc-df8e-424e-bd55-56b4173113d3           193             3
# ...

# %%
pd.read_sql('''select * from "Interaction" order by id desc''',eng).head(100)
# Out:
#       id                         annotation_id   action_type value  \
# 0   1943  bb46c383-715a-4550-96f6-677b5a0c1c1f     elevation    -1
# 1   1942  bb46c383-715a-4550-96f6-677b5a0c1c1f       azimuth   357
# 2   1941  bb46c383-715a-4550-96f6-677b5a0c1c1f     elevation     0
# 3   1940  bb46c383-715a-4550-96f6-677b5a0c1c1f       azimuth    92
# 4   1939  bb46c383-715a-4550-96f6-677b5a0c1c1f     elevation     3
# 5   1938  bb46c383-715a-4550-96f6-677b5a0c1c1f       azimuth   270
# 6   1937  bb46c383-715a-4550-96f6-677b5a0c1c1f  source count     3
# 7   1936  bb46c383-715a-4550-96f6-677b5a0c1c1f    play audio  None
# 8   1935                                   121        submit  None
# 9   1934                                   121     elevation     0
# 10  1933                                   121     elevation     1
# 11  1932                                   121       azimuth   310
# 12  1931                                   121       azimuth   311
# ...

# %%
pd.read_sql('''select * from "Confirmation" order by id desc''',eng).head(10)
# Out:
#     id  recording_id  source_id  location_id annotation_id practice_round
# 0  260            54        110          NaN           102          False
# 1  259            54         68        342.0           102          False
# 2  258            54         64        341.0           102          False
# 3  257            54         59        340.0           102          False
# 4  256            54         42        339.0           102          False
# 5  255           196         82        338.0           101           True
# 6  254           196         56        337.0           101           True
# 7  253           196         50        336.0           101           True
# 8  252           193        125        335.0           100           True
# 9  251           193         98        334.0           100           True

# %%
pd.read_sql('''select id, annotation_id, elevation, practice_round from "Location" order by id desc''',eng).head(10)
# Out:
#     id annotation_id  elevation  practice_round
# 0  372           111          0           False
# 1  371           111          0           False
# 2  370           110          1            True
# 3  369           110          0            True
# 4  368           110          1            True
# 5  367           109          2            True
# 6  366           108          0           False
# 7  365           108          0           False
# 8  364           108          0           False
# 9  363           108          0           False

# %%
pd.read_sql('''select * from "Recording" order by num_annotation desc''',eng)

# %%
pd.read_sql('''select id, recording_name, num_annotation from "Recording" order by num_annotation desc''',eng) 
 # THIS STORES THE ORIGINAL RECORDING TABLE
# Out:
#       id                recording_name  num_annotation
# 0     91   sources_9_recording_154.wav               1
# 1     89     sources_9_recording_8.wav               1
# 2     44   sources_4_recording_123.wav               1
# 3     54    sources_5_recording_77.wav               1
# 4    109    sources_2_recording_80.wav               1
# 5      6   sources_1_recording_154.wav               0
# 6      7   sources_1_recording_177.wav               0
# 7      8   sources_1_recording_194.wav               0
# 8      9    sources_2_recording_14.wav               0
# 9     10    sources_2_recording_27.wav               0
# 10    11    sources_2_recording_37.wav               0
# 11    12    sources_2_recording_60.wav               0
# 12    13    sources_2_recording_80.wav               0
# 13    14   sources_2_recording_155.wav               0
# 14    15   sources_2_recording_166.wav               0
# 15    16   sources_2_recording_193.wav               0
# ...
