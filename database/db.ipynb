# %%
import pandas as pd
from sqlalchemy import *

db_path = 'postgresql://eqpytyddkgzpje:589827916509690e9baa1abd869d99bd85ac3c9902c361d04c1e560c2befd624@ec2-52-54-38-229.compute-1.amazonaws.com:5432/dap64di8scvd9n'
pd.options.display.max_rows = 999

eng = create_engine(db_path)

# %%
pd.read_sql('''select * from "Annotation" where survey_id = 'cdc20bcf-c369-4396-87f8-c15437da0816' ''',eng)
# Out:
#     id                             survey_id  recording_id  source_count  \
# 0  132  cdc20bcf-c369-4396-87f8-c15437da0816           193             2
# 1  133  cdc20bcf-c369-4396-87f8-c15437da0816            83             5
#
#   user_note  practice_round vertical
# 0         3            True     None
# 1                     False     True

# %%
pd.read_sql('''select * from "Interaction" where annotation_id = '132' order by id desc ''',eng)
# Out:
#        id annotation_id   action_type value               timestamp  \
# 0    2391           132        submit  None 2022-02-09 20:45:27.323
# 1    2390           132  source count     2 2022-02-09 20:45:04.648
# 2    2389           132  source count     7 2022-02-09 20:44:59.797
# 3    2388           132    play audio  None 2022-02-09 20:44:48.726
# 4    2387           132     elevation     1 2022-02-09 20:44:15.632
# 5    2386           132       azimuth   212 2022-02-09 20:44:09.963
# 6    2385           132     elevation    -1 2022-02-09 20:43:51.238
# 7    2384           132       azimuth    89 2022-02-09 20:43:49.388
# 8    2383           132     elevation    90 2022-02-09 20:43:16.454
# 9    2382           132     elevation    88 2022-02-09 20:43:12.550
# 10   2381           132       azimuth     0 2022-02-09 20:43:08.518
# 11   2380           132     elevation   -33 2022-02-09 20:43:04.384
# 12   2379           132       azimuth    30 2022-02-09 20:43:01.743
# ...

# %%
pd.read_sql('''select * from "Confirmation" where annotation_id = '132' or annotation_id = '133' ''',eng)
# Out:
#     id  recording_id  source_id  location_id annotation_id  practice_round
# 0  348           193          2        433.0           132            True
# 1  349           193         98        434.0           132            True
# 2  350           193        125          NaN           132            True
# 3  351            83          2        435.0           133           False
# 4  352            83          6        436.0           133           False
# 5  353            83         13        437.0           133           False
# 6  354            83         24        438.0           133           False
# 7  355            83         76        439.0           133           False
# 8  356            83         80          NaN           133           False
# 9  357            83         97          NaN           133           False

# %%
pd.read_sql('''select id, annotation_id, elevation, practice_round from "Location" where annotation_id = '132' ''',eng)
# Out:
#     id annotation_id  elevation  practice_round
# 0  433           132         -1            True
# 1  434           132          1            True

# %%
pd.read_sql('''select * from "Recording" where id = 83 or id = 193''',eng).to_csv("Recording.csv")

# %%
pd.read_sql('''select id, recording_name, num_annotation from "Recording" order by num_annotation desc''',eng) 
 # THIS STORES THE ORIGINAL RECORDING TABLE
# Out:
#       id                recording_name  num_annotation
# 0     91   sources_9_recording_154.wav               1
# 1     89     sources_9_recording_8.wav               1
# 2     44   sources_4_recording_123.wav               1
# 3     54    sources_5_recording_77.wav               1
# 4    109    sources_2_recording_80.wav               1
# 5      6   sources_1_recording_154.wav               0
# 6      7   sources_1_recording_177.wav               0
# 7      8   sources_1_recording_194.wav               0
# 8      9    sources_2_recording_14.wav               0
# 9     10    sources_2_recording_27.wav               0
# 10    11    sources_2_recording_37.wav               0
# 11    12    sources_2_recording_60.wav               0
# 12    13    sources_2_recording_80.wav               0
# 13    14   sources_2_recording_155.wav               0
# 14    15   sources_2_recording_166.wav               0
# 15    16   sources_2_recording_193.wav               0
# ...
