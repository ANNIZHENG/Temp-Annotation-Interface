# %%
import pandas as pd
from sqlalchemy import *

db_path = 'postgresql://eqpytyddkgzpje:589827916509690e9baa1abd869d99bd85ac3c9902c361d04c1e560c2befd624@ec2-52-54-38-229.compute-1.amazonaws.com:5432/dap64di8scvd9n'

pd.options.display.max_rows = 999
eng = create_engine(db_path)

# %%
pd.read_sql('''select * from "Survey" order by id desc ''',eng).head(10)
# Out:
#    id                             survey_id approved  completed  recording_id  \
# 0   1  d5eae805-350b-40fb-9d90-279544f24795     None       True            74
#
#   horizontal_or_vertical
# 0             horizontal

# %%
pd.read_sql('''select * from "Annotation" order by id desc''',eng)
# Out:
#     id                             survey_id  recording_id  source_count  \
# 0   27  d5eae805-350b-40fb-9d90-279544f24795            74             5
# 1   26  d5eae805-350b-40fb-9d90-279544f24795           193             1
# 2   25  d5eae805-350b-40fb-9d90-279544f24795           195             3
# 3   24  d5eae805-350b-40fb-9d90-279544f24795           197             3
# 4   23  d5eae805-350b-40fb-9d90-279544f24795           194             3
# 5   22  d5eae805-350b-40fb-9d90-279544f24795           196             3
# 6   21  d5eae805-350b-40fb-9d90-279544f24795           193             3
# 7   20  26cccc25-5bfc-4dab-9eb0-ceb9ebcf0e90           157             2
# 8   19  26cccc25-5bfc-4dab-9eb0-ceb9ebcf0e90           193             3
# 9   18  713bde8f-582d-4060-b344-5d2e70253dea           112             2
# 10  17  713bde8f-582d-4060-b344-5d2e70253dea           193             3
# 11  16  ccba5d56-d293-4020-8899-bf6cd1dcc8ef           182             3
# ...

# %%
pd.read_sql('''select * from "Confirmation" order by id desc''',eng)
# Out:
#       id  recording_id  source_id  location_id  practice_round annotation_id
# 0    111            74        106          NaN           False            27
# 1    110            74         96         58.0           False            27
# 2    109            74         95         57.0           False            27
# 3    108            74         82         56.0           False            27
# 4    107            74         43         55.0           False            27
# 5    106            74          6         54.0           False            27
# 6    105           193        125          NaN            True            26
# 7    104           193         98          NaN            True            26
# 8    103           193          2         53.0            True            26
# 9    102           195         87         52.0            True            25
# 10   101           195         40         51.0            True            25
# ...

# %%
pd.read_sql('''select * from "Location" order by id desc''', eng)
# Out:
#     id annotation_id  azimuth  elevation  color  practice_round
# 0   58            27      269          3      5           False
# 1   57            27      143          3      4           False
# 2   56            27      270          2      3           False
# 3   55            27      181          1      2           False
# 4   54            27       87          3      1           False
# 5   53            26      271          6      1            True
# 6   52            25      268          1      3            True
# 7   51            25       90          1      2            True
# 8   50            25      183          2      1            True
# 9   49            24       88          0      3            True
# 10  48            24      256          0      2            True
# 11  47            24      270          0      1            True
# 12  46            23      108          0      3            True
# 13  45            23       88          1      2            True
# ...

# %%
pd.read_sql('''select * from "Interaction" order by id desc''',eng)
# Out:
#       id                         annotation_id          action_type value  \
# 0    381                                    27  submit confirmation  None
# 1    380                                    27    submit annotation  None
# 2    379                                    27            elevation     3
# 3    378                                    27              azimuth   269
# 4    377                                    27            elevation     3
# 5    376                                    27              azimuth   143
# 6    375                                    27            elevation     2
# 7    374                                    27              azimuth   270
# 8    373                                    27            elevation     1
# 9    372                                    27              azimuth   181
# 10   371                                    27            elevation     3
# 11   370                                    27              azimuth    87
# ...

# %%
pd.read_sql('''select * from "Recording" order by num_annotation desc''',eng) 
 # THIS STORES THE ORIGINAL RECORDING TABLE
# Out:
#       id                recording_name  num_annotation  num_source vertical
# 0    182   sources_8_recording_123.wav               3           8    False
# 1     74   sources_6_recording_110.wav               1           6     True
# 2    190   sources_10_recording_57.wav               1          10    False
# 3     84    sources_7_recording_87.wav               1           7     True
# 4    132    sources_4_recording_51.wav               1           4    False
# 5    157   sources_5_recording_134.wav               1           5    False
# 6     13    sources_2_recording_80.wav               1           2     True
# 7      8   sources_1_recording_194.wav               0           1     True
# 8      9    sources_2_recording_14.wav               0           2     True
# 9     10    sources_2_recording_27.wav               0           2     True
# 10    11    sources_2_recording_37.wav               0           2     True
# ...
