# %%
import pandas as pd
from sqlalchemy import *

db_path = 'postgresql://eqpytyddkgzpje:589827916509690e9baa1abd869d99bd85ac3c9902c361d04c1e560c2befd624@ec2-52-54-38-229.compute-1.amazonaws.com:5432/dap64di8scvd9n'
pd.options.display.max_rows = 999

eng = create_engine(db_path)

# %%
pd.read_sql('''select * from "Annotation" where survey_id = 'db2eb6cd-9a4e-41b9-a489-85d3e160929b' ''',eng)
# Out:
#     id                             survey_id  recording_id  source_count  \
# 0  134  db2eb6cd-9a4e-41b9-a489-85d3e160929b           193             3
# 1  135  db2eb6cd-9a4e-41b9-a489-85d3e160929b           196             3
# 2  136  db2eb6cd-9a4e-41b9-a489-85d3e160929b           158             3
#
#                                            user_note  practice_round vertical
# 0                           anni noise rooster human            True     None
# 1  anni car left human right front hammer back right            True     None
# 2  anni hammer left to the back flute 90 engine r...           False    False

# %%
pd.read_sql('''select * from "Interaction"''', eng)
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1704                 if not evt_handled:
# -> 1705                     self.dialect.do_execute(
#    1706                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     691     def do_execute(self, cursor, statement, parameters, context=None):
# --> 692         cursor.execute(statement, parameters)
#     693
#
# SyntaxError: syntax error at or near "("
# LINE 1: ...elect * from "Interaction" where annotation_id > int('134')
#                                                                ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-19-16aeba6a186a> in <module>
# ----> 1 pd.read_sql('''select * from "Interaction" where annotation_id > int('134') ''', eng)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     519         )
#     520     else:
# --> 521         return pandas_sql.read_query(
#     522             sql,
#     523             index_col=index_col,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1306         args = _convert_params(sql, params)
#    1307
# -> 1308         result = self.execute(*args)
#    1309         columns = result.keys()
#    1310
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1174     def execute(self, *args, **kwargs):
#    1175         """Simple passthrough to SQLAlchemy connectable"""
# -> 1176         return self.connectable.execution_options().execute(*args, **kwargs)
#    1177
#    1178     def read_table(
#
# <string> in execute(self, statement, *multiparams, **params)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     388         if not skip_warning:
#     389             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 390         return fn(*args, **kwargs)
#     391
#     392     doc = func.__doc__ is not None and func.__doc__ or ""
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    3035         """
#    3036         connection = self.connect(close_with_result=True)
# -> 3037         return connection.execute(statement, *multiparams, **params)
#    3038
#    3039     @util.deprecated_20(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1183             )
#    1184
# -> 1185             return self._exec_driver_sql(
#    1186                 statement,
#    1187                 multiparams,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1482
#    1483         dialect = self.dialect
# -> 1484         ret = self._execute_context(
#    1485             dialect,
#    1486             dialect.execution_ctx_cls._init_statement,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1746
#    1747         except BaseException as e:
# -> 1748             self._handle_dbapi_exception(
#    1749                 e, statement, parameters, cursor, context
#    1750             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1927                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1928             elif should_wrap:
# -> 1929                 util.raise_(
#    1930                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1931                 )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1703                             break
#    1704                 if not evt_handled:
# -> 1705                     self.dialect.do_execute(
#    1706                         cursor, statement, parameters, context
#    1707                     )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     690
#     691     def do_execute(self, cursor, statement, parameters, context=None):
# --> 692         cursor.execute(statement, parameters)
#     693
#     694     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.SyntaxError) syntax error at or near "("
# LINE 1: ...elect * from "Interaction" where annotation_id > int('134')
#                                                                ^
#
# [SQL: select * from "Interaction" where annotation_id > int('134') ]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
pd.read_sql('''select * from "Confirmation" where annotation_id = '134' or annotation_id = '135' or annotation_id = '136' ''',eng)
# Out:
#      id  recording_id  source_id  location_id annotation_id  practice_round
# 0   358           193          2        440.0           134            True
# 1   359           193         98        441.0           134            True
# 2   360           193        125        442.0           134            True
# 3   361           196         50        443.0           135            True
# 4   362           196         56        444.0           135            True
# 5   363           196         82        445.0           135            True
# 6   364           158          4        446.0           136           False
# 7   365           158         25        447.0           136           False
# 8   366           158         37        448.0           136           False
# 9   367           158         50          NaN           136           False
# 10  368           158         73          NaN           136           False

# %%
pd.read_sql('''with cte as (select "Recording".id as recording_id, "Recording".recording_name as recording_name, 
"Recording_Joint_Source".source_id as source_id from "Recording" inner join "Recording_Joint_Source" on "Recording".id = "Recording_Joint_Source".recording_id) 
select "Source".file_name as file_name, "Source".specific_class as specific_class, cte.recording_name as recording_name from "Source" inner join cte on "Source".id = cte.source_id where cte.recording_id >192 order by recording_name asc''',eng)
# Out:
#                        file_name     specific_class  \
# 0            airplane_2_norm.wav           airplane
# 1                 cat_3_norm.wav        cat meowing
# 2               cello_1_norm.wav              cello
# 3         dog_barking_3_norm.wav        dog barking
# 4   electric_saw_type_2_norm.wav  electric saw-type
# 5           hammering_1_norm.wav          hammering
# 6           hammering_5_norm.wav          hammering
# 7                horn_2_norm.wav           car horn
# 8      person_talking_4_norm.wav     person talking
# 9               piano_3_norm.wav              piano
# 10            rooster_3_norm.wav            rooster
# 11              siren_5_norm.wav              siren
# 12        small_crowd_1_norm.wav     people talking
# 13             toilet_1_norm.wav             toilet
# 14             violin_4_norm.wav             violin
#
#                  recording_name
# 0     sources_3_recording_8.wav
# 1   sources_3_recording_160.wav
# 2   sources_3_recording_130.wav
# 3   sources_3_recording_150.wav
# 4   sources_3_recording_160.wav
# 5   sources_3_recording_130.wav
# 6    sources_3_recording_57.wav
# 7    sources_3_recording_57.wav
# 8    sources_3_recording_57.wav
# 9   sources_3_recording_160.wav
# 10    sources_3_recording_8.wav
# 11  sources_3_recording_130.wav
# 12    sources_3_recording_8.wav
# 13  sources_3_recording_150.wav
# 14  sources_3_recording_150.wav

# %%
pd.read_sql('''select * from "Source"''',eng)
# Out:
#       id                     file_name                  coarse_class  \
# 0      1           airplane_1_norm.wav  large transportation methods
# 1      2           airplane_2_norm.wav  large transportation methods
# 2      3           airplane_3_norm.wav  large transportation methods
# 3      4              birds_1_norm.wav                       animals
# 4      5              birds_3_norm.wav                       animals
# 5      6            boiling_1_norm.wav               domestic sounds
# 6      7            boiling_2_norm.wav               domestic sounds
# 7      8            boiling_3_norm.wav               domestic sounds
# 8      9            boiling_4_norm.wav               domestic sounds
# 9     10          car_alarm_1_norm.wav                        alarms
# 10    11          car_alarm_2_norm.wav                        alarms
# 11    12          car_alarm_3_norm.wav                        alarms
# 12    13          car_alarm_4_norm.wav                        alarms
# 13    14                cat_3_norm.wav                       animals
# 14    15                cat_5_norm.wav                       animals
# 15    16              cello_1_norm.wav                         music
# 16    17              cello_2_norm.wav                         music
# 17    18              cello_3_norm.wav                         music
# 18    19              cello_4_norm.wav                         music
# 19    20           chainsaw_1_norm.wav               saw_type_sounds
# 20    21           chainsaw_2_norm.wav               saw_type_sounds
# 21    22           chainsaw_3_norm.wav               saw_type_sounds
# 22    23           chainsaw_4_norm.wav               saw_type_sounds
# 23    24           clarinet_1_norm.wav                         music
# 24    25           clarinet_3_norm.wav                         music
# 25    26       dog_barking_10_norm.wav                       animals
# 26    27       dog_barking_11_norm.wav                       animals
# 27    28        dog_barking_2_norm.wav                       animals
# 28    29        dog_barking_3_norm.wav                       animals
# 29    30        dog_barking_4_norm.wav                       animals
# 30    31        dog_barking_5_norm.wav                       animals
# 31    32        dog_barking_6_norm.wav                       animals
# 32    33        dog_barking_7_norm.wav                       animals
# 33    34        dog_barking_9_norm.wav                       animals
# 34    35              dryer_1_norm.wav               domestic sounds
# 35    36              dryer_2_norm.wav               domestic sounds
# 36    37              dryer_3_norm.wav               domestic sounds
# 37    38              dryer_4_norm.wav               domestic sounds
# 38    39  electric_saw_type_1_norm.wav               saw_type_sounds
# 39    40  electric_saw_type_2_norm.wav               saw_type_sounds
# 40    41  electric_saw_type_3_norm.wav               saw_type_sounds
# 41    42              flute_1_norm.wav                         music
# 42    43              flute_2_norm.wav                         music
# 43    44              flute_3_norm.wav                         music
# 44    45              flute_4_norm.wav                         music
# 45    46          hammering_1_norm.wav                 impact sounds
# 46    47          hammering_2_norm.wav                 impact sounds
# 47    48          hammering_3_norm.wav                 impact sounds
# 48    49          hammering_4_norm.wav                 impact sounds
# 49    50          hammering_5_norm.wav                 impact sounds
# 50    51         helicopter_1_norm.wav  large transportation methods
# 51    52         helicopter_2_norm.wav  large transportation methods
# 52    53         helicopter_3_norm.wav  large transportation methods
# 53    54         helicopter_4_norm.wav  large transportation methods
# 54    55               horn_1_norm.wav                        alarms
# 55    56               horn_2_norm.wav                        alarms
# 56    57               horn_3_norm.wav                        alarms
# 57    58               horn_4_norm.wav                        alarms
# 58    59         jackhammer_1_norm.wav                 impact sounds
# 59    60         jackhammer_2_norm.wav                 impact sounds
# 60    61         jackhammer_3_norm.wav                 impact sounds
# 61    62               keys_1_norm.wav               domestic sounds
# 62    63               keys_2_norm.wav               domestic sounds
# 63    64               keys_3_norm.wav               domestic sounds
# 64    65       large_engine_1_norm.wav                       engines
# 65    66      large_engine_10_norm.wav                       engines
# 66    67      large_engine_11_norm.wav                       engines
# 67    68       large_engine_2_norm.wav                       engines
# 68    69       large_engine_3_norm.wav                       engines
# 69    70       large_engine_5_norm.wav                       engines
# 70    71       large_engine_6_norm.wav                       engines
# 71    72       large_engine_7_norm.wav                       engines
# 72    73       large_engine_8_norm.wav                       engines
# 73    74       large_engine_9_norm.wav                       engines
# 74    75      medium_engine_1_norm.wav                       engines
# 75    76      medium_engine_2_norm.wav                       engines
# 76    77      medium_engine_3_norm.wav                       engines
# 77    78      medium_engine_5_norm.wav                       engines
# 78    79     person_talking_1_norm.wav                   human voice
# 79    80     person_talking_2_norm.wav                   human voice
# 80    81     person_talking_3_norm.wav                   human voice
# 81    82     person_talking_4_norm.wav                   human voice
# 82    83     person_talking_5_norm.wav                   human voice
# 83    84     person_talking_6_norm.wav                   human voice
# 84    85              piano_1_norm.wav                         music
# 85    86              piano_2_norm.wav                         music
# 86    87              piano_3_norm.wav                         music
# 87    88              piano_4_norm.wav                         music
# 88    89    river_waterfall_1_norm.wav                natural sounds
# 89    90    river_waterfall_2_norm.wav                natural sounds
# 90    91    river_waterfall_3_norm.wav                natural sounds
# 91    92    river_waterfall_4_norm.wav                natural sounds
# 92    93    river_waterfall_5_norm.wav                natural sounds
# 93    94    river_waterfall_6_norm.wav                natural sounds
# 94    95    river_waterfall_7_norm.wav                natural sounds
# 95    96            rooster_1_norm.wav                       animals
# 96    97            rooster_2_norm.wav                       animals
# 97    98            rooster_3_norm.wav                       animals
# 98    99            rooster_4_norm.wav                       animals
# 99   100              siren_1_norm.wav                        alarms
# 100  101              siren_2_norm.wav                        alarms
# 101  102              siren_3_norm.wav                        alarms
# 102  103              siren_4_norm.wav                        alarms
# 103  104              siren_5_norm.wav                        alarms
# 104  105              siren_6_norm.wav                        alarms
# 105  106              siren_8_norm.wav                        alarms
# 106  107              siren_9_norm.wav                        alarms
# 107  108             toilet_3_norm.wav               domestic sounds
# 108  109              train_1_norm.wav  large transportation methods
# 109  110              train_2_norm.wav  large transportation methods
# 110  111              train_3_norm.wav  large transportation methods
# 111  112              train_4_norm.wav  large transportation methods
# 112  113            trumpet_1_norm.wav                         music
# 113  114            trumpet_2_norm.wav                         music
# 114  115            trumpet_3_norm.wav                         music
# 115  116            trumpet_4_norm.wav                         music
# 116  117             violin_1_norm.wav                         music
# 117  118             violin_2_norm.wav                         music
# 118  119             violin_4_norm.wav                         music
# 119  120               wind_1_norm.wav                natural sounds
# 120  121               wind_2_norm.wav                natural sounds
# 121  122               wind_3_norm.wav                natural sounds
# 122  123               wind_4_norm.wav                natural sounds
# 123  124             toilet_1_norm.wav               domestic sounds
# 124  125        small_crowd_1_norm.wav                   human voice
#
#         specific_class bandwidth_continuity
# 0             airplane     broad continuous
# 1             airplane     broad continuous
# 2             airplane     broad continuous
# 3                birds    narrow continuous
# 4                birds    narrow continuous
# 5      boiling liquids     broad continuous
# 6      boiling liquids     broad continuous
# 7      boiling liquids     broad continuous
# 8      boiling liquids     broad continuous
# 9            car alarm    narrow continuous
# 10           car alarm    narrow continuous
# 11           car alarm    narrow continuous
# 12           car alarm    narrow continuous
# 13         cat meowing     narrow transient
# 14         cat meowing     narrow transient
# 15               cello    narrow continuous
# 16               cello    narrow continuous
# 17               cello    narrow continuous
# 18               cello    narrow continuous
# 19            chainsaw     broad continuous
# 20            chainsaw     broad continuous
# 21            chainsaw     broad continuous
# 22            chainsaw     broad continuous
# 23            clarinet    narrow continuous
# 24            clarinet    narrow continuous
# 25         dog barking      broad transient
# 26         dog barking      broad transient
# 27         dog barking      broad transient
# 28         dog barking      broad transient
# 29         dog barking      broad transient
# 30         dog barking      broad transient
# 31         dog barking      broad transient
# 32         dog barking      broad transient
# 33         dog barking      broad transient
# 34               dryer     broad continuous
# 35               dryer     broad continuous
# 36               dryer     broad continuous
# 37               dryer     broad continuous
# 38   electric saw-type     broad continuous
# 39   electric saw-type     broad continuous
# 40   electric saw-type     broad continuous
# 41               flute    narrow continuous
# 42               flute    narrow continuous
# 43               flute    narrow continuous
# 44               flute    narrow continuous
# 45           hammering      broad transient
# 46           hammering      broad transient
# 47           hammering      broad transient
# 48           hammering      broad transient
# 49           hammering      broad transient
# 50          helicopter     broad continuous
# 51          helicopter     broad continuous
# 52          helicopter     broad continuous
# 53          helicopter     broad continuous
# 54            car horn      broad transient
# 55            car horn      broad transient
# 56            car horn      broad transient
# 57            car horn      broad transient
# 58          jackhammer      broad transient
# 59          jackhammer      broad transient
# 60          jackhammer      broad transient
# 61                keys    narrow continuous
# 62                keys    narrow continuous
# 63                keys    narrow continuous
# 64        large engine     broad continuous
# 65        large engine     broad continuous
# 66        large engine     broad continuous
# 67        large engine     broad continuous
# 68        large engine     broad continuous
# 69        large engine     broad continuous
# 70        large engine     broad continuous
# 71        large engine     broad continuous
# 72        large engine     broad continuous
# 73        large engine     broad continuous
# 74       medium engine     broad continuous
# 75       medium engine     broad continuous
# 76       medium engine     broad continuous
# 77       medium engine     broad continuous
# 78      person talking    narrow continuous
# 79      person talking    narrow continuous
# 80      person talking    narrow continuous
# 81      person talking    narrow continuous
# 82      person talking    narrow continuous
# 83      person talking    narrow continuous
# 84               piano    narrow continuous
# 85               piano    narrow continuous
# 86               piano    narrow continuous
# 87               piano    narrow continuous
# 88     river_waterfall     broad continuous
# 89     river_waterfall     broad continuous
# 90     river_waterfall     broad continuous
# 91     river_waterfall     broad continuous
# 92     river_waterfall     broad continuous
# 93     river_waterfall     broad continuous
# 94     river_waterfall     broad continuous
# 95             rooster      broad transient
# 96             rooster      broad transient
# 97             rooster      broad transient
# 98             rooster      broad transient
# 99               siren    narrow continuous
# 100              siren    narrow continuous
# 101              siren    narrow continuous
# 102              siren    narrow continuous
# 103              siren    narrow continuous
# 104              siren    narrow continuous
# 105              siren    narrow continuous
# 106              siren    narrow continuous
# 107             toilet     broad continuous
# 108              train     broad continuous
# 109              train     broad continuous
# 110              train     broad continuous
# 111              train     broad continuous
# 112            trumpet    narrow continuous
# 113            trumpet    narrow continuous
# 114            trumpet    narrow continuous
# 115            trumpet    narrow continuous
# 116             violin    narrow continuous
# 117             violin    narrow continuous
# 118             violin    narrow continuous
# 119               wind     broad continuous
# 120               wind     broad continuous
# 121               wind     broad continuous
# 122               wind     broad continuous
# 123             toilet     broad continuous
# 124     people talking    narrow continuous

# %%
pd.read_sql('''select id, recording_name, num_annotation from "Recording" order by num_annotation asc''',eng) 
 # THIS STORES THE ORIGINAL RECORDING TABLE
# Out:
#       id                recording_name  num_annotation
# 0    154    sources_5_recording_99.wav               0
# 1      2    sources_1_recording_45.wav               0
# 2      3    sources_1_recording_58.wav               0
# 3      4   sources_1_recording_107.wav               0
# 4      5   sources_1_recording_111.wav               0
# 5      6   sources_1_recording_154.wav               0
# 6      7   sources_1_recording_177.wav               0
# 7      8   sources_1_recording_194.wav               0
# 8      9    sources_2_recording_14.wav               0
# 9     10    sources_2_recording_27.wav               0
# 10    11    sources_2_recording_37.wav               0
# 11    12    sources_2_recording_60.wav               0
# 12    13    sources_2_recording_80.wav               0
# 13    14   sources_2_recording_155.wav               0
# 14    15   sources_2_recording_166.wav               0
# 15    16   sources_2_recording_193.wav               0
# 16    17     sources_3_recording_3.wav               0
# 17    18     sources_3_recording_5.wav               0
# 18    19    sources_3_recording_22.wav               0
# 19    20    sources_3_recording_32.wav               0
# 20    21    sources_3_recording_33.wav               0
# 21    22    sources_3_recording_54.wav               0
# 22    23    sources_3_recording_59.wav               0
# 23    24    sources_3_recording_86.wav               0
# 24    25    sources_3_recording_87.wav               0
# 25    26   sources_3_recording_102.wav               0
# 26    27   sources_3_recording_133.wav               0
# 27    28   sources_3_recording_147.wav               0
# 28    29   sources_3_recording_151.wav               0
# 29    30   sources_3_recording_154.wav               0
# 30    31   sources_3_recording_178.wav               0
# 31    32   sources_3_recording_182.wav               0
# 32    33    sources_4_recording_13.wav               0
# 33    34    sources_4_recording_18.wav               0
# 34    35    sources_4_recording_37.wav               0
# 35    36    sources_4_recording_51.wav               0
# 36    37    sources_4_recording_52.wav               0
# 37    38    sources_4_recording_55.wav               0
# 38    39    sources_4_recording_83.wav               0
# 39    40    sources_4_recording_88.wav               0
# 40    41    sources_4_recording_92.wav               0
# 41    42    sources_4_recording_97.wav               0
# 42    43   sources_4_recording_111.wav               0
# 43    45   sources_4_recording_134.wav               0
# 44    46   sources_4_recording_153.wav               0
# 45    47   sources_4_recording_157.wav               0
# 46    48   sources_4_recording_161.wav               0
# 47    49     sources_5_recording_9.wav               0
# 48    50    sources_5_recording_32.wav               0
# 49    51    sources_5_recording_48.wav               0
# 50    52    sources_5_recording_57.wav               0
# 51    53    sources_5_recording_62.wav               0
# 52    55    sources_5_recording_83.wav               0
# 53    56    sources_5_recording_93.wav               0
# 54    57    sources_5_recording_96.wav               0
# 55    58    sources_5_recording_99.wav               0
# 56    59   sources_5_recording_111.wav               0
