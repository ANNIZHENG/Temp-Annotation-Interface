# %%
import pandas as pd
from sqlalchemy import *

db_path = 'postgresql://eqpytyddkgzpje:589827916509690e9baa1abd869d99bd85ac3c9902c361d04c1e560c2befd624@ec2-52-54-38-229.compute-1.amazonaws.com:5432/dap64di8scvd9n'
pd.options.display.max_rows = 999

eng = create_engine(db_path)

# %%
pd.read_sql('''select * from "Survey" order by id desc ''',eng).head(1)
# Out:
#     id                             survey_id
# 0  117  f496b1eb-669f-4bbf-892e-4be58ce66bc8

# %%
pd.read_sql('''select * from "Annotation" where survey_id = 'f496b1eb-669f-4bbf-892e-4be58ce66bc8' ''',eng)
# Out:
#     id                             survey_id  recording_id  source_count  \
# 0  155  f496b1eb-669f-4bbf-892e-4be58ce66bc8           193             3
# 1  156  f496b1eb-669f-4bbf-892e-4be58ce66bc8           186             6
#
#                   user_note  practice_round vertical
# 0         anni test 2 start            True     None
# 1  anni test actual 2 start           False    False

# %%
pd.read_sql('''select * from "Confirmation" where annotation_id = '155' or annotation_id = '156' order by id desc''',eng)
# Out:
#      id  recording_id  source_id  location_id annotation_id  practice_round
# 0   420           186        109          NaN           156           False
# 1   419           186         97          NaN           156           False
# 2   418           186         89          NaN           156           False
# 3   417           186         86        511.0           156           False
# 4   416           186         79        510.0           156           False
# 5   415           186         74        509.0           156           False
# 6   414           186         63        508.0           156           False
# 7   413           186         57        507.0           156           False
# 8   412           186         21        506.0           156           False
# 9   411           193        125        505.0           155            True
# 10  410           193         98        504.0           155            True
# ...

# %%
pd.read_sql('''select * from "Interaction" where annotation_id = '155' or annotation_id = '156' order by id desc''',eng)
# Out:
#       id annotation_id          action_type value               timestamp  \
# 0   2666           154    submit annotation  None 2022-02-12 07:22:11.596
# 1   2665           154            elevation    -2 2022-02-12 07:22:10.934
# 2   2664           154              azimuth   243 2022-02-12 07:22:10.118
# 3   2663           154            elevation     1 2022-02-12 07:22:09.218
# 4   2662           154              azimuth    90 2022-02-12 07:22:08.368
# 5   2661           154            elevation    -2 2022-02-12 07:22:07.250
# 6   2660           154              azimuth   269 2022-02-12 07:22:06.268
# 7   2659           154            elevation     1 2022-02-12 07:22:03.503
# 8   2658           154              azimuth   359 2022-02-12 07:22:02.264
# 9   2657           154         source count     4 2022-02-12 07:22:00.021
# 10  2656           154           play audio  None 2022-02-12 07:21:46.980
# 11  2655           154           play audio  None 2022-02-12 07:21:43.314
# ...

# %%
pd.read_sql('''select * from "Location" where annotation_id = '153' or annotation_id = '154' ''', eng)
# Out:
#     id annotation_id  azimuth  elevation  practice_round  color
# 0  496           153      270          1            True      1
# 1  497           153      215          2            True      2
# 2  498           153      332         -1            True      3
# 3  499           154      359          1           False      1
# 4  500           154      269         -2           False      2
# 5  501           154       90          1           False      3
# 6  502           154      243         -2           False      4

# %%
pd.read_sql('''select * from "Recording" order by num_annotation asc''',eng) 
 # THIS STORES THE ORIGINAL RECORDING TABLE
# Out:
#       id                recording_name  num_annotation  num_source vertical
# 0    154    sources_5_recording_99.wav               0           5    False
# 1      2    sources_1_recording_45.wav               0           1     True
# 2      3    sources_1_recording_58.wav               0           1     True
# 3      4   sources_1_recording_107.wav               0           1     True
# 4      5   sources_1_recording_111.wav               0           1     True
# 5      6   sources_1_recording_154.wav               0           1     True
# 6      7   sources_1_recording_177.wav               0           1     True
# 7      8   sources_1_recording_194.wav               0           1     True
# 8      9    sources_2_recording_14.wav               0           2     True
# 9     10    sources_2_recording_27.wav               0           2     True
# 10    11    sources_2_recording_37.wav               0           2     True
# ...
